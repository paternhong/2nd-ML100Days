# %% [markdown]
# ## 作業一:
# 1. 你選的這組資料為何重要？
#     心血管疾病和我們息息相關
# 2. 資料從何而來(tips: 譬如提供者是誰、以什麼方式蒐集)
#     https://www.kaggle.com/ronitf/heart-disease-uci
# 3. 蒐集而來的資料型態為何？
#     CSV
# 4. 這組資料想解決的問題如何評估？
#     年齡、性別、飲食及生活習慣對於心血管疾病的影響。

# %% [markdown]
# ## 作業二:
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     假設載客區域和業績之間有關連
#     假設不同時段和業績之間有關連
#     假設駕駛態度和業績之間有關連
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     從司機詢問而來
#     客戶反饋、問卷調查
# 3. 蒐集而來的資料型態為何
#     Text
#     Int
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     根據搜集來的資料，評估不同載客區域和時段的載客人數
#     根據車隊的資料，評估駕駛人態度優良對於駕駛業績的提升是否有影響

# %% [markdown]
# ## 作業三:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)  # 0~100之間等差的101個數值的一維陣列

y = (x_lin + np.random.randn(101) * 5) * w + b  # 對應x_lin中101個數值的一維陣列

plt.plot(x_lin, y, 'b.', label = 'data points')  # 利用plot函數畫出(x_lin, y) 對應的101個藍色點
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.013

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
def mean_square_error(y, yh):
    '''
    Args:
    y: 實際值
    yp: 預測值
    Return:
    mse
    '''
    mse = sum(np.power((y - yh), 2)) / len(y)  # 或是sum((y-yh)**2) / len(y) 
    return mse
MSE = mean_square_error(y, y_hat) 
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 233.308
